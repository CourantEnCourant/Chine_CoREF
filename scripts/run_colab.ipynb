# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Change cwd
import os

print(f'Default directory: {os.getcwd()}')
wd = ('./drive/Othercomputers/MacbookAir/coref_personal/scripts/')

try:
  os.chdir(wd)
  print(f'Current directory: {os.getcwd()}')
except FileNotFoundError:
  print(f'Directory {wd} not found')
# Out:
# Default directory: /content/drive/Othercomputers/MacbookAir/coref_personal/scripts
# Directory ./drive/Othercomputers/MacbookAir/coref_personal/scripts/ not found

# %%
from classify_tweets import label2id, id2label, predict_agriculture

input_txt = '../data/raw/tweets.txt'
output_csv = 'tweets_agriculture.csv'

predict_agriculture(input_txt, output_csv)
# Out:
# 273950 texts to classify.
# Using cuda:0.
# 100%|██████████| 273950/273950 [54:56<00:00, 83.11it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-1561452f95d4> in <cell line: 6>()
#       4 output_csv = 'tweets_agriculture.csv'
#       5
# ----> 6 predict_agriculture(input_txt, output_csv)
#
# /content/drive/Othercomputers/MacbookAir/coref_personal/scripts/classify_tweets.py in predict_agriculture(input_txt, output_csv)
#      45         f.write(headers + '\n')
#      46         for text_classified in texts_classified:
# ---> 47             text = ','.join(text_classified)
#      48             f.write(text + '\n')
#      49
#
# TypeError: sequence item 0: expected str instance, int found
